# %%
import numpy as np
import pandas as pd
import math

# %% [markdown]
# # Load Data

# %%
raw_data  = pd.read_csv("./Dataset/BOM.csv")

# %%
raw_data.head(-50)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145435  2017-06-01    Uluru      5.6     19.4       0.0          NaN
# 145436  2017-06-02    Uluru      1.5     19.2       0.0          NaN
# 145437  2017-06-03    Uluru      3.8     19.8       0.0          NaN
# 145438  2017-06-04    Uluru      4.5     18.8       0.0          NaN
# 145439  2017-06-05    Uluru      4.9     20.7       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# ## جدا کردن سطون های عددی و سطون های رشته ای

# %%
dis_attr=[
    "Date",
    "Location",
]
